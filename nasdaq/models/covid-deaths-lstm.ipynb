# %% [markdown]
# Related urls, will remove once finished:
# - https://www.tensorflow.org/tutorials/structured_data/time_series#multi-step_models

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import itertools

# %%
file_path = "../data/parsed_dataset.csv"
date_column = "Date_reported"
target_column = "New_deaths"
df = pd.read_csv(file_path, parse_dates=True)
df = df[[date_column, target_column, "New_cases", "Cumulative_cases"]]

df = df.groupby(date_column).sum().reset_index()
df.set_index(date_column, inplace=True)
df = df.dropna()
dates = df.index.values

# %%
# Creating a data structure (it does not work when you have only one feature)
def create_data(
    df, n_future, n_past, train_test_split_percentage, validation_split_percentage
):
    n_feature = df.shape[1]
    x_data, y_data = [], []

    for i in range(n_past, len(df) - n_future + 1):
        x_data.append(df[i - n_past : i, 0:n_feature])
        y_data.append(df[i + n_future - 1 : i + n_future, 0])

    split_training_test_starting_point = int(
        round(train_test_split_percentage * len(x_data))
    )
    split_train_validation_starting_point = int(
        round(split_training_test_starting_point * (1 - validation_split_percentage))
    )

    x_train = x_data[:split_train_validation_starting_point]
    y_train = y_data[:split_train_validation_starting_point]

    # if you want to choose the validation set by yourself, uncomment the below code.
    x_val = x_data[
        split_train_validation_starting_point:split_training_test_starting_point
    ]
    y_val = x_data[
        split_train_validation_starting_point:split_training_test_starting_point
    ]

    x_test = x_data[split_training_test_starting_point:]
    y_test = y_data[split_training_test_starting_point:]

    return (
        np.array(x_train),
        np.array(x_test),
        np.array(x_val),
        np.array(y_train),
        np.array(y_test),
        np.array(y_val),
    )

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
scaled_data.shape
# Out:
# (1420, 3)

# %%
# Number of days you want to predict into the future
# Number of past days you want to use to predict the future

X_train, X_test, X_val, y_train, y_test, y_val = create_data(
    scaled_data,
    n_future=1,
    n_past=30,
    train_test_split_percentage=0.9,
    validation_split_percentage=0,
)

# %%
print(X_train.shape)
print(X_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (1251, 30, 3)
# (139, 30, 3)
# (1251, 1)
# (139, 1)

# %%
# ------------------LSTM-----------------------
regressor = Sequential()
regressor.add(
    LSTM(
        units=16,
        return_sequences=True,
        input_shape=(X_train.shape[1], X_train.shape[2]),
    )
)
regressor.add(Dropout(0.2))

regressor.add(LSTM(units=16, return_sequences=False))
regressor.add(Dropout(0.2))
regressor.add(Dense(units=1, activation="linear"))
regressor.compile(
    optimizer=tf.keras.optimizers.Adam(), loss="mse", metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 16)            1280
#
#  dropout (Dropout)           (None, 30, 16)            0
#
#  lstm_1 (LSTM)               (None, 16)                2112
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 3409 (13.32 KB)
# Trainable params: 3409 (13.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
es = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=5)
# mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# fit model
history = regressor.fit(
    X_train, y_train, validation_split=0.3, epochs=200, batch_size=64, callbacks=[es]
)
# Out:
# Epoch 1/200
# 14/14 [==============================] - 2s 42ms/step - loss: 1.1828 - root_mean_squared_error: 1.0876 - val_loss: 0.5279 - val_root_mean_squared_error: 0.7266
# Epoch 2/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.6565 - root_mean_squared_error: 0.8103 - val_loss: 0.3956 - val_root_mean_squared_error: 0.6289
# Epoch 3/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4953 - root_mean_squared_error: 0.7038 - val_loss: 0.2835 - val_root_mean_squared_error: 0.5324
# Epoch 4/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4543 - root_mean_squared_error: 0.6741 - val_loss: 0.2163 - val_root_mean_squared_error: 0.4651
# Epoch 5/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4254 - root_mean_squared_error: 0.6522 - val_loss: 0.1670 - val_root_mean_squared_error: 0.4086
# Epoch 6/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4161 - root_mean_squared_error: 0.6451 - val_loss: 0.1367 - val_root_mean_squared_error: 0.3697
# Epoch 7/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3928 - root_mean_squared_error: 0.6268 - val_loss: 0.1175 - val_root_mean_squared_error: 0.3428
# Epoch 8/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3912 - root_mean_squared_error: 0.6254 - val_loss: 0.1093 - val_root_mean_squared_error: 0.3307
# Epoch 9/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3730 - root_mean_squared_error: 0.6107 - val_loss: 0.1022 - val_root_mean_squared_error: 0.3198
# Epoch 10/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3775 - root_mean_squared_error: 0.6144 - val_loss: 0.0985 - val_root_mean_squared_error: 0.3138
# Epoch 11/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3627 - root_mean_squared_error: 0.6023 - val_loss: 0.1028 - val_root_mean_squared_error: 0.3206
# Epoch 12/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3687 - root_mean_squared_error: 0.6072 - val_loss: 0.1020 - val_root_mean_squared_error: 0.3194
# Epoch 13/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3614 - root_mean_squared_error: 0.6012 - val_loss: 0.0986 - val_root_mean_squared_error: 0.3140
# Epoch 14/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3757 - root_mean_squared_error: 0.6130 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3077
# Epoch 15/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3725 - root_mean_squared_error: 0.6104 - val_loss: 0.1027 - val_root_mean_squared_error: 0.3204
# Epoch 16/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3594 - root_mean_squared_error: 0.5995 - val_loss: 0.1010 - val_root_mean_squared_error: 0.3179
# Epoch 17/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3531 - root_mean_squared_error: 0.5942 - val_loss: 0.0989 - val_root_mean_squared_error: 0.3144
# Epoch 18/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.3689 - root_mean_squared_error: 0.6074 - val_loss: 0.1026 - val_root_mean_squared_error: 0.3203
# Epoch 19/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.3592 - root_mean_squared_error: 0.5993 - val_loss: 0.0947 - val_root_mean_squared_error: 0.3078
# Epoch 19: early stopping

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'root_mean_squared_error', 'val_loss', 'val_root_mean_squared_error'])

# %%
fig = plt.figure(figsize=(20, 7))
fig.add_subplot(121)

# Accuracy
plt.plot(history.epoch, history.history["root_mean_squared_error"], label="rmse")
plt.plot(
    history.epoch, history.history["val_root_mean_squared_error"], label="val_rmse"
)

plt.title("RMSE", fontsize=18)
plt.xlabel("Epochs", fontsize=15)
plt.ylabel("RMSE", fontsize=15)
plt.grid(alpha=0.3)
plt.legend()


# Adding Subplot 1 (For Loss)
fig.add_subplot(122)

plt.plot(history.epoch, history.history["loss"], label="loss")
plt.plot(history.epoch, history.history["val_loss"], label="val_loss")

plt.title("Loss", fontsize=18)
plt.xlabel("Epochs", fontsize=15)
plt.ylabel("Loss", fontsize=15)
plt.grid(alpha=0.3)
plt.legend()

plt.show()

# %%
results = regressor.evaluate(X_test, y_test)
print("test loss, test acc:", np.round(results, 4))
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0192 - root_mean_squared_error: 0.1384
# test loss, test acc: [0.0192 0.1384]

# %%
# detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
# tf.config.experimental_connect_to_cluster(tpu)
# tf.tpu.experimental.initialize_tpu_system(tpu)

# instantiate a distribution strategy
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)


def LSTM_HyperParameter_Tuning(config, x_train, y_train, x_test, y_test):
    (
        first_additional_layer,
        second_additional_layer,
        third_additional_layer,
        n_neurons,
        n_batch_size,
        dropout,
    ) = config
    possible_combinations = list(
        itertools.product(
            first_additional_layer,
            second_additional_layer,
            third_additional_layer,
            n_neurons,
            n_batch_size,
            dropout,
        )
    )

    print(possible_combinations)
    print("\n")

    hist = []

    for i in range(0, len(possible_combinations)):
        print(f"{i+1}th combination: \n")
        print("--------------------------------------------------------------------")

        (
            first_additional_layer,
            second_additional_layer,
            third_additional_layer,
            n_neurons,
            n_batch_size,
            dropout,
        ) = possible_combinations[i]

        # instantiating the model in the strategy scope creates the model on the TPU
        # with tpu_strategy.scope():
        regressor = Sequential()
        regressor.add(
            LSTM(
                units=n_neurons,
                return_sequences=True,
                input_shape=(x_train.shape[1], x_train.shape[2]),
            )
        )
        regressor.add(Dropout(dropout))

        if first_additional_layer:
            regressor.add(LSTM(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        if second_additional_layer:
            regressor.add(LSTM(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        if third_additional_layer:
            regressor.add(GRU(units=n_neurons, return_sequences=True))
            regressor.add(Dropout(dropout))

        regressor.add(LSTM(units=n_neurons, return_sequences=False))
        regressor.add(Dropout(dropout))
        regressor.add(Dense(units=1, activation="linear"))
        regressor.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss="mse",
            metrics=[tf.keras.metrics.RootMeanSquaredError()],
        )

        es = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=5)
        """''
        From the mentioned article above --> If a validation dataset is specified to the fit() function via the validation_data or v
        alidation_split arguments,then the loss on the validation dataset will be made available via the name “val_loss.”
        """ ""

        file_path = "best_model.h5"

        mc = ModelCheckpoint(
            file_path, monitor="val_loss", mode="min", verbose=1, save_best_only=True
        )

        """''
        cb = Callback(...)  # First, callbacks must be instantiated.
        cb_list = [cb, ...]  # Then, one or more callbacks that you intend to use must be added to a Python list.
        model.fit(..., callbacks=cb_list)  # Finally, the list of callbacks is provided to the callback argument when fitting the model.
        """ ""

        regressor.fit(
            x_train,
            y_train,
            validation_split=0.3,
            epochs=1000,
            batch_size=n_batch_size,
            callbacks=[es, mc],
            verbose=0,
        )

        # load the best model
        # regressor = load_model('best_model.h5')

        train_accuracy = regressor.evaluate(x_train, y_train, verbose=0)
        test_accuracy = regressor.evaluate(x_test, y_test, verbose=0)

        hist.append(
            list(
                (
                    first_additional_layer,
                    second_additional_layer,
                    third_additional_layer,
                    n_neurons,
                    n_batch_size,
                    dropout,
                    train_accuracy,
                    test_accuracy,
                )
            )
        )

        print(
            f"{str(i)}-th combination = {possible_combinations[i]} \n train accuracy: {train_accuracy} and test accuracy: {test_accuracy}"
        )

    return hist

# %%
config = [
    [True, False],
    [True, False],
    [True, False],
    [64, 128, 256],
    [7, 28,365],
    [0.2],
]

# list of lists --> [[first_additional_layer], [second_additional_layer], [third_additional_layer], [n_neurons], [n_batch_size], [dropout]]

hist = LSTM_HyperParameter_Tuning(
    config, X_train, y_train, X_test, y_test
)  # change x_train shape
# Out:
# [(True, True, True, 64, 7, 0.2), (True, True, True, 64, 28, 0.2), (True, True, True, 64, 365, 0.2), (True, True, True, 128, 7, 0.2), (True, True, True, 128, 28, 0.2), (True, True, True, 128, 365, 0.2), (True, True, True, 256, 7, 0.2), (True, True, True, 256, 28, 0.2), (True, True, True, 256, 365, 0.2), (True, True, False, 64, 7, 0.2), (True, True, False, 64, 28, 0.2), (True, True, False, 64, 365, 0.2), (True, True, False, 128, 7, 0.2), (True, True, False, 128, 28, 0.2), (True, True, False, 128, 365, 0.2), (True, True, False, 256, 7, 0.2), (True, True, False, 256, 28, 0.2), (True, True, False, 256, 365, 0.2), (True, False, True, 64, 7, 0.2), (True, False, True, 64, 28, 0.2), (True, False, True, 64, 365, 0.2), (True, False, True, 128, 7, 0.2), (True, False, True, 128, 28, 0.2), (True, False, True, 128, 365, 0.2), (True, False, True, 256, 7, 0.2), (True, False, True, 256, 28, 0.2), (True, False, True, 256, 365, 0.2), (True, False, False, 64, 7, 0.2), (True, False, False, 64, 28, 0.2), (True, False, False, 64, 365, 0.2), (True, False, False, 128, 7, 0.2), (True, False, False, 128, 28, 0.2), (True, False, False, 128, 365, 0.2), (True, False, False, 256, 7, 0.2), (True, False, False, 256, 28, 0.2), (True, False, False, 256, 365, 0.2), (False, True, True, 64, 7, 0.2), (False, True, True, 64, 28, 0.2), (False, True, True, 64, 365, 0.2), (False, True, True, 128, 7, 0.2), (False, True, True, 128, 28, 0.2), (False, True, True, 128, 365, 0.2), (False, True, True, 256, 7, 0.2), (False, True, True, 256, 28, 0.2), (False, True, True, 256, 365, 0.2), (False, True, False, 64, 7, 0.2), (False, True, False, 64, 28, 0.2), (False, True, False, 64, 365, 0.2), (False, True, False, 128, 7, 0.2), (False, True, False, 128, 28, 0.2), (False, True, False, 128, 365, 0.2), (False, True, False, 256, 7, 0.2), (False, True, False, 256, 28, 0.2), (False, True, False, 256, 365, 0.2), (False, False, True, 64, 7, 0.2), (False, False, True, 64, 28, 0.2), (False, False, True, 64, 365, 0.2), (False, False, True, 128, 7, 0.2), (False, False, True, 128, 28, 0.2), (False, False, True, 128, 365, 0.2), (False, False, True, 256, 7, 0.2), (False, False, True, 256, 28, 0.2), (False, False, True, 256, 365, 0.2), (False, False, False, 64, 7, 0.2), (False, False, False, 64, 28, 0.2), (False, False, False, 64, 365, 0.2), (False, False, False, 128, 7, 0.2), (False, False, False, 128, 28, 0.2), (False, False, False, 128, 365, 0.2), (False, False, False, 256, 7, 0.2), (False, False, False, 256, 28, 0.2), (False, False, False, 256, 365, 0.2)]
#
#
# 1th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.14887, saving model to best_model.h5
# /home/samuell/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss did not improve from 0.14887
#
# Epoch 3: val_loss improved from 0.14887 to 0.08455, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.08455 to 0.08251, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.08251
#
# Epoch 6: val_loss did not improve from 0.08251
#
# Epoch 7: val_loss did not improve from 0.08251
#
# Epoch 8: val_loss did not improve from 0.08251
#
# Epoch 9: val_loss did not improve from 0.08251
# Epoch 9: early stopping
# 0-th combination = (True, True, True, 64, 7, 0.2)
#  train accuracy: [0.28595665097236633, 0.5347491502761841] and test accuracy: [0.054470255970954895, 0.23338863253593445]
# 2th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.09394, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.09394
#
# Epoch 3: val_loss improved from 0.09394 to 0.09307, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.09307 to 0.08753, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.08753
#
# Epoch 6: val_loss did not improve from 0.08753
#
# Epoch 7: val_loss did not improve from 0.08753
#
# Epoch 8: val_loss did not improve from 0.08753
#
# Epoch 9: val_loss did not improve from 0.08753
# Epoch 9: early stopping
# 1-th combination = (True, True, True, 64, 28, 0.2)
#  train accuracy: [0.26803058385849, 0.5177167057991028] and test accuracy: [0.0050013717263937, 0.070720374584198]
# 3th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.41649, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.41649 to 0.26696, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.26696
#
# Epoch 4: val_loss improved from 0.26696 to 0.24084, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.24084 to 0.12166, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.12166 to 0.08951, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.08951 to 0.08883, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.08883
#
# Epoch 9: val_loss did not improve from 0.08883
#
# Epoch 10: val_loss did not improve from 0.08883
#
# Epoch 11: val_loss did not improve from 0.08883
#
# Epoch 12: val_loss did not improve from 0.08883
# Epoch 12: early stopping
# 2-th combination = (True, True, True, 64, 365, 0.2)
#  train accuracy: [0.2799489200115204, 0.5291019678115845] and test accuracy: [0.010334951803088188, 0.10166096687316895]
# 4th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.09285, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.09285
#
# Epoch 3: val_loss did not improve from 0.09285
#
# Epoch 4: val_loss did not improve from 0.09285
#
# Epoch 5: val_loss improved from 0.09285 to 0.08372, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.08372 to 0.07866, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.07866
#
# Epoch 8: val_loss did not improve from 0.07866
#
# Epoch 9: val_loss did not improve from 0.07866
#
# Epoch 10: val_loss improved from 0.07866 to 0.07206, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.07206
#
# Epoch 12: val_loss did not improve from 0.07206
#
# Epoch 13: val_loss did not improve from 0.07206
#
# Epoch 14: val_loss did not improve from 0.07206
#
# Epoch 15: val_loss did not improve from 0.07206
# Epoch 15: early stopping
# 3-th combination = (True, True, True, 128, 7, 0.2)
#  train accuracy: [0.12749753892421722, 0.3570679724216461] and test accuracy: [0.08848393708467484, 0.29746249318122864]
# 5th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.17887, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.17887 to 0.13054, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.13054 to 0.10808, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.10808 to 0.09600, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.09600
#
# Epoch 6: val_loss did not improve from 0.09600
#
# Epoch 7: val_loss improved from 0.09600 to 0.08646, saving model to best_model.h5
#
# Epoch 8: val_loss improved from 0.08646 to 0.08239, saving model to best_model.h5
#
# Epoch 9: val_loss did not improve from 0.08239
#
# Epoch 10: val_loss did not improve from 0.08239
#
# Epoch 11: val_loss did not improve from 0.08239
#
# Epoch 12: val_loss improved from 0.08239 to 0.08126, saving model to best_model.h5
#
# Epoch 13: val_loss did not improve from 0.08126
#
# Epoch 14: val_loss did not improve from 0.08126
#
# Epoch 15: val_loss did not improve from 0.08126
#
# Epoch 16: val_loss did not improve from 0.08126
#
# Epoch 17: val_loss did not improve from 0.08126
# Epoch 17: early stopping
# 4-th combination = (True, True, True, 128, 28, 0.2)
#  train accuracy: [0.2004968225955963, 0.4477687180042267] and test accuracy: [0.007607267238199711, 0.08721964806318283]
# 6th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.13730, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.13730
#
# Epoch 3: val_loss improved from 0.13730 to 0.13084, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.13084 to 0.09818, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.09818
#
# Epoch 6: val_loss did not improve from 0.09818
#
# Epoch 7: val_loss did not improve from 0.09818
#
# Epoch 8: val_loss did not improve from 0.09818
#
# Epoch 9: val_loss improved from 0.09818 to 0.09064, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.09064
#
# Epoch 11: val_loss did not improve from 0.09064
#
# Epoch 12: val_loss did not improve from 0.09064
#
# Epoch 13: val_loss did not improve from 0.09064
#
# Epoch 14: val_loss did not improve from 0.09064
# Epoch 14: early stopping
# 5-th combination = (True, True, True, 128, 365, 0.2)
#  train accuracy: [0.2719452679157257, 0.5214837193489075] and test accuracy: [0.004934459924697876, 0.07024571299552917]
# 7th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08148, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.08148
#
# Epoch 3: val_loss improved from 0.08148 to 0.07686, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.07686
#
# Epoch 5: val_loss did not improve from 0.07686
#
# Epoch 6: val_loss did not improve from 0.07686
#
# Epoch 7: val_loss did not improve from 0.07686
#
# Epoch 8: val_loss did not improve from 0.07686
# Epoch 8: early stopping
# 6-th combination = (True, True, True, 256, 7, 0.2)
#  train accuracy: [0.1768648475408554, 0.4205530285835266] and test accuracy: [0.03690962865948677, 0.1921187937259674]
# 8th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.16540, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.16540 to 0.16080, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.16080 to 0.08031, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08031
#
# Epoch 5: val_loss did not improve from 0.08031
#
# Epoch 6: val_loss did not improve from 0.08031
#
# Epoch 7: val_loss did not improve from 0.08031
#
# Epoch 8: val_loss did not improve from 0.08031
# Epoch 8: early stopping
# 7-th combination = (True, True, True, 256, 28, 0.2)
#  train accuracy: [0.3393590450286865, 0.5825453400611877] and test accuracy: [0.19960731267929077, 0.44677433371543884]
# 9th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.21587, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.21587
#
# Epoch 3: val_loss did not improve from 0.21587
#
# Epoch 4: val_loss improved from 0.21587 to 0.13749, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.13749
#
# Epoch 6: val_loss improved from 0.13749 to 0.10552, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.10552
#
# Epoch 8: val_loss improved from 0.10552 to 0.08465, saving model to best_model.h5
#
# Epoch 9: val_loss did not improve from 0.08465
#
# Epoch 10: val_loss did not improve from 0.08465
#
# Epoch 11: val_loss did not improve from 0.08465
#
# Epoch 12: val_loss did not improve from 0.08465
#
# Epoch 13: val_loss did not improve from 0.08465
# Epoch 13: early stopping
# 8-th combination = (True, True, True, 256, 365, 0.2)
#  train accuracy: [0.28933513164520264, 0.53789883852005] and test accuracy: [0.034615810960531235, 0.18605324625968933]
# 10th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.10094, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.10094
#
# Epoch 3: val_loss improved from 0.10094 to 0.08566, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08566
#
# Epoch 5: val_loss did not improve from 0.08566
#
# Epoch 6: val_loss did not improve from 0.08566
#
# Epoch 7: val_loss did not improve from 0.08566
#
# Epoch 8: val_loss did not improve from 0.08566
# Epoch 8: early stopping
# 9-th combination = (True, True, False, 64, 7, 0.2)
#  train accuracy: [0.27462196350097656, 0.5240438580513] and test accuracy: [0.0907144621014595, 0.3011884093284607]
# 11th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.11984, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.11984 to 0.11775, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.11775 to 0.08831, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08831
#
# Epoch 5: val_loss improved from 0.08831 to 0.08787, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.08787 to 0.08416, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.08416
#
# Epoch 8: val_loss did not improve from 0.08416
#
# Epoch 9: val_loss did not improve from 0.08416
#
# Epoch 10: val_loss did not improve from 0.08416
#
# Epoch 11: val_loss did not improve from 0.08416
# Epoch 11: early stopping
# 10-th combination = (True, True, False, 64, 28, 0.2)
#  train accuracy: [0.25804850459098816, 0.5079847574234009] and test accuracy: [0.00908565241843462, 0.09531868994235992]
# 12th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.32386, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.32386 to 0.15450, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.15450
#
# Epoch 4: val_loss did not improve from 0.15450
#
# Epoch 5: val_loss improved from 0.15450 to 0.12924, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.12924 to 0.08948, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.08948 to 0.08748, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.08748
#
# Epoch 9: val_loss did not improve from 0.08748
#
# Epoch 10: val_loss did not improve from 0.08748
#
# Epoch 11: val_loss did not improve from 0.08748
#
# Epoch 12: val_loss did not improve from 0.08748
# Epoch 12: early stopping
# 11-th combination = (True, True, False, 64, 365, 0.2)
#  train accuracy: [0.27562853693962097, 0.5250033736228943] and test accuracy: [0.005368846468627453, 0.07327241450548172]
# 13th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.11824, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.11824 to 0.08009, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.08009
#
# Epoch 4: val_loss did not improve from 0.08009
#
# Epoch 5: val_loss did not improve from 0.08009
#
# Epoch 6: val_loss did not improve from 0.08009
#
# Epoch 7: val_loss did not improve from 0.08009
# Epoch 7: early stopping
# 12-th combination = (True, True, False, 128, 7, 0.2)
#  train accuracy: [0.1957983672618866, 0.4424910843372345] and test accuracy: [0.005804029293358326, 0.07618418335914612]
# 14th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08253, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.08253 to 0.08235, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.08235
#
# Epoch 4: val_loss did not improve from 0.08235
#
# Epoch 5: val_loss did not improve from 0.08235
#
# Epoch 6: val_loss improved from 0.08235 to 0.07656, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.07656
#
# Epoch 8: val_loss did not improve from 0.07656
#
# Epoch 9: val_loss improved from 0.07656 to 0.07638, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.07638
#
# Epoch 11: val_loss did not improve from 0.07638
#
# Epoch 12: val_loss did not improve from 0.07638
#
# Epoch 13: val_loss did not improve from 0.07638
#
# Epoch 14: val_loss improved from 0.07638 to 0.07622, saving model to best_model.h5
#
# Epoch 15: val_loss did not improve from 0.07622
#
# Epoch 16: val_loss did not improve from 0.07622
#
# Epoch 17: val_loss did not improve from 0.07622
#
# Epoch 18: val_loss did not improve from 0.07622
#
# Epoch 19: val_loss did not improve from 0.07622
# Epoch 19: early stopping
# 13-th combination = (True, True, False, 128, 28, 0.2)
#  train accuracy: [0.19114071130752563, 0.43719643354415894] and test accuracy: [0.009338523261249065, 0.09663603454828262]
# 15th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.11128, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.11128
#
# Epoch 3: val_loss improved from 0.11128 to 0.10440, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.10440 to 0.09450, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.09450 to 0.08797, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.08797 to 0.08367, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.08367
#
# Epoch 8: val_loss did not improve from 0.08367
#
# Epoch 9: val_loss improved from 0.08367 to 0.08073, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.08073
#
# Epoch 11: val_loss did not improve from 0.08073
#
# Epoch 12: val_loss did not improve from 0.08073
#
# Epoch 13: val_loss did not improve from 0.08073
#
# Epoch 14: val_loss did not improve from 0.08073
# Epoch 14: early stopping
# 14-th combination = (True, True, False, 128, 365, 0.2)
#  train accuracy: [0.2943311631679535, 0.5425229668617249] and test accuracy: [0.04190678521990776, 0.20471146702766418]
# 16th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08049, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.08049
#
# Epoch 3: val_loss did not improve from 0.08049
#
# Epoch 4: val_loss did not improve from 0.08049
#
# Epoch 5: val_loss improved from 0.08049 to 0.07998, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.07998
#
# Epoch 7: val_loss did not improve from 0.07998
#
# Epoch 8: val_loss did not improve from 0.07998
#
# Epoch 9: val_loss did not improve from 0.07998
#
# Epoch 10: val_loss did not improve from 0.07998
# Epoch 10: early stopping
# 15-th combination = (True, True, False, 256, 7, 0.2)
#  train accuracy: [0.1240672767162323, 0.35223186016082764] and test accuracy: [0.011672496795654297, 0.10803932696580887]
# 17th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.11749, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.11749
#
# Epoch 3: val_loss improved from 0.11749 to 0.08412, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08412
#
# Epoch 5: val_loss did not improve from 0.08412
#
# Epoch 6: val_loss improved from 0.08412 to 0.08134, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.08134
#
# Epoch 8: val_loss did not improve from 0.08134
#
# Epoch 9: val_loss did not improve from 0.08134
#
# Epoch 10: val_loss did not improve from 0.08134
#
# Epoch 11: val_loss improved from 0.08134 to 0.07780, saving model to best_model.h5
#
# Epoch 12: val_loss did not improve from 0.07780
#
# Epoch 13: val_loss did not improve from 0.07780
#
# Epoch 14: val_loss did not improve from 0.07780
#
# Epoch 15: val_loss did not improve from 0.07780
#
# Epoch 16: val_loss improved from 0.07780 to 0.07205, saving model to best_model.h5
#
# Epoch 17: val_loss did not improve from 0.07205
#
# Epoch 18: val_loss did not improve from 0.07205
#
# Epoch 19: val_loss did not improve from 0.07205
#
# Epoch 20: val_loss did not improve from 0.07205
#
# Epoch 21: val_loss did not improve from 0.07205
# Epoch 21: early stopping
# 16-th combination = (True, True, False, 256, 28, 0.2)
#  train accuracy: [0.08887095004320145, 0.29811230301856995] and test accuracy: [0.008595536462962627, 0.09271211922168732]
# 18th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.19011, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.19011
#
# Epoch 3: val_loss improved from 0.19011 to 0.11797, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.11797
#
# Epoch 5: val_loss improved from 0.11797 to 0.09282, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.09282
#
# Epoch 7: val_loss did not improve from 0.09282
#
# Epoch 8: val_loss improved from 0.09282 to 0.08012, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 0.08012 to 0.07967, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.07967
#
# Epoch 11: val_loss did not improve from 0.07967
#
# Epoch 12: val_loss did not improve from 0.07967
#
# Epoch 13: val_loss did not improve from 0.07967
#
# Epoch 14: val_loss did not improve from 0.07967
# Epoch 14: early stopping
# 17-th combination = (True, True, False, 256, 365, 0.2)
#  train accuracy: [0.28349775075912476, 0.5324450731277466] and test accuracy: [0.04153197631239891, 0.2037939578294754]
# 19th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.15367, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.15367 to 0.11062, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.11062 to 0.10191, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.10191 to 0.10088, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.10088 to 0.09609, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.09609 to 0.08801, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.08801 to 0.07936, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.07936
#
# Epoch 9: val_loss did not improve from 0.07936
#
# Epoch 10: val_loss improved from 0.07936 to 0.07634, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.07634
#
# Epoch 12: val_loss improved from 0.07634 to 0.07205, saving model to best_model.h5
#
# Epoch 13: val_loss did not improve from 0.07205
#
# Epoch 14: val_loss improved from 0.07205 to 0.07121, saving model to best_model.h5
#
# Epoch 15: val_loss did not improve from 0.07121
#
# Epoch 16: val_loss did not improve from 0.07121
#
# Epoch 17: val_loss did not improve from 0.07121
#
# Epoch 18: val_loss did not improve from 0.07121
#
# Epoch 19: val_loss improved from 0.07121 to 0.06995, saving model to best_model.h5
#
# Epoch 20: val_loss did not improve from 0.06995
#
# Epoch 21: val_loss did not improve from 0.06995
#
# Epoch 22: val_loss did not improve from 0.06995
#
# Epoch 23: val_loss did not improve from 0.06995
#
# Epoch 24: val_loss did not improve from 0.06995
# Epoch 24: early stopping
# 18-th combination = (True, False, True, 64, 7, 0.2)
#  train accuracy: [0.07015951722860336, 0.26487642526626587] and test accuracy: [0.0051065897569060326, 0.07146040350198746]
# 20th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08156, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.08156
#
# Epoch 3: val_loss did not improve from 0.08156
#
# Epoch 4: val_loss did not improve from 0.08156
#
# Epoch 5: val_loss did not improve from 0.08156
#
# Epoch 6: val_loss did not improve from 0.08156
# Epoch 6: early stopping
# 19-th combination = (True, False, True, 64, 28, 0.2)
#  train accuracy: [0.37717825174331665, 0.6141483783721924] and test accuracy: [0.09971624612808228, 0.31577879190444946]
# 21th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.45663, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.45663 to 0.21169, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.21169 to 0.19545, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.19545
#
# Epoch 5: val_loss improved from 0.19545 to 0.16555, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.16555 to 0.09961, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.09961 to 0.09047, saving model to best_model.h5
#
# Epoch 8: val_loss improved from 0.09047 to 0.08640, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 0.08640 to 0.08534, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.08534
#
# Epoch 11: val_loss did not improve from 0.08534
#
# Epoch 12: val_loss did not improve from 0.08534
#
# Epoch 13: val_loss did not improve from 0.08534
#
# Epoch 14: val_loss did not improve from 0.08534
# Epoch 14: early stopping
# 20-th combination = (True, False, True, 64, 365, 0.2)
#  train accuracy: [0.27222713828086853, 0.5217539072036743] and test accuracy: [0.015097180381417274, 0.12287058681249619]
# 22th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.16275, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.16275 to 0.09707, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.09707 to 0.08274, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08274
#
# Epoch 5: val_loss did not improve from 0.08274
#
# Epoch 6: val_loss did not improve from 0.08274
#
# Epoch 7: val_loss did not improve from 0.08274
#
# Epoch 8: val_loss did not improve from 0.08274
# Epoch 8: early stopping
# 21-th combination = (True, False, True, 128, 7, 0.2)
#  train accuracy: [0.20063577592372894, 0.44792383909225464] and test accuracy: [0.004339824430644512, 0.06587734073400497]
# 23th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.16216, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.16216
#
# Epoch 3: val_loss improved from 0.16216 to 0.08873, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.08873 to 0.08506, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.08506
#
# Epoch 6: val_loss did not improve from 0.08506
#
# Epoch 7: val_loss improved from 0.08506 to 0.08195, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.08195
#
# Epoch 9: val_loss did not improve from 0.08195
#
# Epoch 10: val_loss did not improve from 0.08195
#
# Epoch 11: val_loss did not improve from 0.08195
#
# Epoch 12: val_loss did not improve from 0.08195
# Epoch 12: early stopping
# 22-th combination = (True, False, True, 128, 28, 0.2)
#  train accuracy: [0.20889706909656525, 0.4570525884628296] and test accuracy: [0.012249051593244076, 0.11067543178796768]
# 24th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.12120, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.12120
#
# Epoch 3: val_loss did not improve from 0.12120
#
# Epoch 4: val_loss improved from 0.12120 to 0.08220, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.08220 to 0.08131, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.08131
#
# Epoch 7: val_loss did not improve from 0.08131
#
# Epoch 8: val_loss did not improve from 0.08131
#
# Epoch 9: val_loss did not improve from 0.08131
#
# Epoch 10: val_loss did not improve from 0.08131
# Epoch 10: early stopping
# 23-th combination = (True, False, True, 128, 365, 0.2)
#  train accuracy: [0.2704717814922333, 0.5200690031051636] and test accuracy: [0.010510507971048355, 0.10252077132463455]
# 25th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08677, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.08677
#
# Epoch 3: val_loss did not improve from 0.08677
#
# Epoch 4: val_loss did not improve from 0.08677
#
# Epoch 5: val_loss did not improve from 0.08677
#
# Epoch 6: val_loss did not improve from 0.08677
# Epoch 6: early stopping
# 24-th combination = (True, False, True, 256, 7, 0.2)
#  train accuracy: [0.1542966365814209, 0.39280611276626587] and test accuracy: [0.004807140212506056, 0.06933354586362839]
# 26th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.12365, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.12365 to 0.07749, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.07749
#
# Epoch 4: val_loss did not improve from 0.07749
#
# Epoch 5: val_loss did not improve from 0.07749
#
# Epoch 6: val_loss did not improve from 0.07749
#
# Epoch 7: val_loss did not improve from 0.07749
# Epoch 7: early stopping
# 25-th combination = (True, False, True, 256, 28, 0.2)
#  train accuracy: [0.21166540682315826, 0.4600710868835449] and test accuracy: [0.0697060078382492, 0.2640189528465271]
# 27th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.16328, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.16328
#
# Epoch 3: val_loss improved from 0.16328 to 0.10824, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.10824
#
# Epoch 5: val_loss did not improve from 0.10824
#
# Epoch 6: val_loss improved from 0.10824 to 0.09363, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.09363
#
# Epoch 8: val_loss improved from 0.09363 to 0.09280, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 0.09280 to 0.08965, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.08965
#
# Epoch 11: val_loss did not improve from 0.08965
#
# Epoch 12: val_loss did not improve from 0.08965
#
# Epoch 13: val_loss did not improve from 0.08965
#
# Epoch 14: val_loss did not improve from 0.08965
# Epoch 14: early stopping
# 26-th combination = (True, False, True, 256, 365, 0.2)
#  train accuracy: [0.2665777802467346, 0.5163117051124573] and test accuracy: [0.009799123741686344, 0.09899052232503891]
# 28th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08833, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.08833
#
# Epoch 3: val_loss did not improve from 0.08833
#
# Epoch 4: val_loss did not improve from 0.08833
#
# Epoch 5: val_loss did not improve from 0.08833
#
# Epoch 6: val_loss did not improve from 0.08833
# Epoch 6: early stopping
# 27-th combination = (True, False, False, 64, 7, 0.2)
#  train accuracy: [0.2737133502960205, 0.5231761932373047] and test accuracy: [0.006159571465104818, 0.07848294079303741]
# 29th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.11007, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.11007 to 0.10727, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.10727 to 0.08719, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08719
#
# Epoch 5: val_loss improved from 0.08719 to 0.08433, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.08433
#
# Epoch 7: val_loss improved from 0.08433 to 0.08155, saving model to best_model.h5
#
# Epoch 8: val_loss improved from 0.08155 to 0.07823, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 0.07823 to 0.07776, saving model to best_model.h5
#
# Epoch 10: val_loss improved from 0.07776 to 0.07717, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.07717
#
# Epoch 12: val_loss did not improve from 0.07717
#
# Epoch 13: val_loss did not improve from 0.07717
#
# Epoch 14: val_loss did not improve from 0.07717
#
# Epoch 15: val_loss did not improve from 0.07717
# Epoch 15: early stopping
# 28-th combination = (True, False, False, 64, 28, 0.2)
#  train accuracy: [0.22093121707439423, 0.470033198595047] and test accuracy: [0.0064896466210484505, 0.08055834472179413]
# 30th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.42524, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.42524 to 0.21123, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.21123 to 0.14838, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.14838
#
# Epoch 5: val_loss improved from 0.14838 to 0.13775, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.13775 to 0.09729, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.09729 to 0.08336, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.08336
#
# Epoch 9: val_loss did not improve from 0.08336
#
# Epoch 10: val_loss did not improve from 0.08336
#
# Epoch 11: val_loss did not improve from 0.08336
#
# Epoch 12: val_loss did not improve from 0.08336
# Epoch 12: early stopping
# 29-th combination = (True, False, False, 64, 365, 0.2)
#  train accuracy: [0.2671017646789551, 0.5168188810348511] and test accuracy: [0.005704929586499929, 0.07553098350763321]
# 31th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08750, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.08750
#
# Epoch 3: val_loss did not improve from 0.08750
#
# Epoch 4: val_loss did not improve from 0.08750
#
# Epoch 5: val_loss did not improve from 0.08750
#
# Epoch 6: val_loss did not improve from 0.08750
# Epoch 6: early stopping
# 30-th combination = (True, False, False, 128, 7, 0.2)
#  train accuracy: [0.17955055832862854, 0.42373406887054443] and test accuracy: [0.014655722305178642, 0.1210608184337616]
# 32th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.13770, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.13770 to 0.11176, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.11176 to 0.09211, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.09211
#
# Epoch 5: val_loss did not improve from 0.09211
#
# Epoch 6: val_loss improved from 0.09211 to 0.09162, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.09162 to 0.09046, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.09046
#
# Epoch 9: val_loss did not improve from 0.09046
#
# Epoch 10: val_loss did not improve from 0.09046
#
# Epoch 11: val_loss did not improve from 0.09046
#
# Epoch 12: val_loss did not improve from 0.09046
# Epoch 12: early stopping
# 31-th combination = (True, False, False, 128, 28, 0.2)
#  train accuracy: [0.1993754655122757, 0.4465147852897644] and test accuracy: [0.005848801229149103, 0.07647745311260223]
# 33th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.10206, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.10206
#
# Epoch 3: val_loss improved from 0.10206 to 0.08579, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08579
#
# Epoch 5: val_loss improved from 0.08579 to 0.07814, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.07814
#
# Epoch 7: val_loss did not improve from 0.07814
#
# Epoch 8: val_loss did not improve from 0.07814
#
# Epoch 9: val_loss did not improve from 0.07814
#
# Epoch 10: val_loss did not improve from 0.07814
# Epoch 10: early stopping
# 32-th combination = (True, False, False, 128, 365, 0.2)
#  train accuracy: [0.26517897844314575, 0.5149553418159485] and test accuracy: [0.010461704805493355, 0.10228247195482254]
# 34th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.32621, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.32621 to 0.08412, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.08412
#
# Epoch 4: val_loss did not improve from 0.08412
#
# Epoch 5: val_loss did not improve from 0.08412
#
# Epoch 6: val_loss did not improve from 0.08412
#
# Epoch 7: val_loss did not improve from 0.08412
# Epoch 7: early stopping
# 33-th combination = (True, False, False, 256, 7, 0.2)
#  train accuracy: [0.16139604151248932, 0.40174126625061035] and test accuracy: [0.010020580142736435, 0.10010284930467606]
# 35th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.07862, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.07862
#
# Epoch 3: val_loss did not improve from 0.07862
#
# Epoch 4: val_loss did not improve from 0.07862
#
# Epoch 5: val_loss did not improve from 0.07862
#
# Epoch 6: val_loss did not improve from 0.07862
# Epoch 6: early stopping
# 34-th combination = (True, False, False, 256, 28, 0.2)
#  train accuracy: [0.254587322473526, 0.504566490650177] and test accuracy: [0.019662512466311455, 0.14022308588027954]
# 36th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.13498, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.13498
#
# Epoch 3: val_loss improved from 0.13498 to 0.09934, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.09934
#
# Epoch 5: val_loss improved from 0.09934 to 0.08139, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.08139
#
# Epoch 7: val_loss did not improve from 0.08139
#
# Epoch 8: val_loss did not improve from 0.08139
#
# Epoch 9: val_loss did not improve from 0.08139
#
# Epoch 10: val_loss did not improve from 0.08139
# Epoch 10: early stopping
# 35-th combination = (True, False, False, 256, 365, 0.2)
#  train accuracy: [0.2829569876194, 0.5319370031356812] and test accuracy: [0.013277956284582615, 0.1152300164103508]
# 37th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.16313, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.16313 to 0.11457, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.11457 to 0.11323, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 0.11323 to 0.09098, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.09098 to 0.08069, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.08069
#
# Epoch 7: val_loss did not improve from 0.08069
#
# Epoch 8: val_loss did not improve from 0.08069
#
# Epoch 9: val_loss did not improve from 0.08069
#
# Epoch 10: val_loss did not improve from 0.08069
# Epoch 10: early stopping
# 36-th combination = (False, True, True, 64, 7, 0.2)
#  train accuracy: [0.18276207149028778, 0.42750680446624756] and test accuracy: [0.026346450671553612, 0.16231590509414673]
# 38th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08607, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.08607
#
# Epoch 3: val_loss did not improve from 0.08607
#
# Epoch 4: val_loss did not improve from 0.08607
#
# Epoch 5: val_loss improved from 0.08607 to 0.08289, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.08289
#
# Epoch 7: val_loss did not improve from 0.08289
#
# Epoch 8: val_loss did not improve from 0.08289
#
# Epoch 9: val_loss did not improve from 0.08289
#
# Epoch 10: val_loss did not improve from 0.08289
# Epoch 10: early stopping
# 37-th combination = (False, True, True, 64, 28, 0.2)
#  train accuracy: [0.2544771432876587, 0.5044572949409485] and test accuracy: [0.00540138827636838, 0.07349413633346558]
# 39th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.38037, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.38037 to 0.20777, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.20777
#
# Epoch 4: val_loss did not improve from 0.20777
#
# Epoch 5: val_loss improved from 0.20777 to 0.17248, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.17248 to 0.11371, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.11371 to 0.10723, saving model to best_model.h5
#
# Epoch 8: val_loss improved from 0.10723 to 0.10668, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 0.10668 to 0.10000, saving model to best_model.h5
#
# Epoch 10: val_loss improved from 0.10000 to 0.09769, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.09769
#
# Epoch 12: val_loss did not improve from 0.09769
#
# Epoch 13: val_loss did not improve from 0.09769
#
# Epoch 14: val_loss did not improve from 0.09769
#
# Epoch 15: val_loss improved from 0.09769 to 0.09752, saving model to best_model.h5
#
# Epoch 16: val_loss improved from 0.09752 to 0.09536, saving model to best_model.h5
#
# Epoch 17: val_loss did not improve from 0.09536
#
# Epoch 18: val_loss did not improve from 0.09536
#
# Epoch 19: val_loss did not improve from 0.09536
#
# Epoch 20: val_loss did not improve from 0.09536
#
# Epoch 21: val_loss did not improve from 0.09536
# Epoch 21: early stopping
# 38-th combination = (False, True, True, 64, 365, 0.2)
#  train accuracy: [0.27030420303344727, 0.5199078917503357] and test accuracy: [0.022952867671847343, 0.15150204300880432]
# 40th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08706, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.08706
#
# Epoch 3: val_loss did not improve from 0.08706
#
# Epoch 4: val_loss improved from 0.08706 to 0.08171, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.08171
#
# Epoch 6: val_loss did not improve from 0.08171
#
# Epoch 7: val_loss did not improve from 0.08171
#
# Epoch 8: val_loss did not improve from 0.08171
#
# Epoch 9: val_loss did not improve from 0.08171
# Epoch 9: early stopping
# 39-th combination = (False, True, True, 128, 7, 0.2)
#  train accuracy: [0.2671944797039032, 0.516908586025238] and test accuracy: [0.14569415152072906, 0.3816990256309509]
# 41th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.10376, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.10376 to 0.10101, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.10101
#
# Epoch 4: val_loss improved from 0.10101 to 0.08284, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.08284
#
# Epoch 6: val_loss improved from 0.08284 to 0.08135, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.08135
#
# Epoch 8: val_loss did not improve from 0.08135
#
# Epoch 9: val_loss did not improve from 0.08135
#
# Epoch 10: val_loss did not improve from 0.08135
#
# Epoch 11: val_loss did not improve from 0.08135
# Epoch 11: early stopping
# 40-th combination = (False, True, True, 128, 28, 0.2)
#  train accuracy: [0.1948176622390747, 0.4413815438747406] and test accuracy: [0.011032428592443466, 0.10503536462783813]
# 42th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.12623, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.12623
#
# Epoch 3: val_loss did not improve from 0.12623
#
# Epoch 4: val_loss improved from 0.12623 to 0.08910, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.08910 to 0.08729, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.08729
#
# Epoch 7: val_loss did not improve from 0.08729
#
# Epoch 8: val_loss did not improve from 0.08729
#
# Epoch 9: val_loss did not improve from 0.08729
#
# Epoch 10: val_loss did not improve from 0.08729
# Epoch 10: early stopping
# 41-th combination = (False, True, True, 128, 365, 0.2)
#  train accuracy: [0.2853706181049347, 0.53420090675354] and test accuracy: [0.007681527640670538, 0.08764432370662689]
# 43th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.11158, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.11158 to 0.08738, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.08738
#
# Epoch 4: val_loss did not improve from 0.08738
#
# Epoch 5: val_loss did not improve from 0.08738
#
# Epoch 6: val_loss did not improve from 0.08738
#
# Epoch 7: val_loss did not improve from 0.08738
# Epoch 7: early stopping
# 42-th combination = (False, True, True, 256, 7, 0.2)
#  train accuracy: [0.21316806972026825, 0.46170127391815186] and test accuracy: [0.12640412151813507, 0.35553357005119324]
# 44th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.16959, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.16959 to 0.09343, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.09343
#
# Epoch 4: val_loss improved from 0.09343 to 0.08106, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.08106
#
# Epoch 6: val_loss did not improve from 0.08106
#
# Epoch 7: val_loss did not improve from 0.08106
#
# Epoch 8: val_loss did not improve from 0.08106
#
# Epoch 9: val_loss did not improve from 0.08106
# Epoch 9: early stopping
# 43-th combination = (False, True, True, 256, 28, 0.2)
#  train accuracy: [0.23839397728443146, 0.4882560670375824] and test accuracy: [0.057983722537755966, 0.24079810082912445]
# 45th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.17058, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.17058
#
# Epoch 3: val_loss improved from 0.17058 to 0.12671, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.12671
#
# Epoch 5: val_loss did not improve from 0.12671
#
# Epoch 6: val_loss did not improve from 0.12671
#
# Epoch 7: val_loss improved from 0.12671 to 0.11307, saving model to best_model.h5
#
# Epoch 8: val_loss improved from 0.11307 to 0.11070, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 0.11070 to 0.10794, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 0.10794
#
# Epoch 11: val_loss improved from 0.10794 to 0.09831, saving model to best_model.h5
#
# Epoch 12: val_loss did not improve from 0.09831
#
# Epoch 13: val_loss did not improve from 0.09831
#
# Epoch 14: val_loss did not improve from 0.09831
#
# Epoch 15: val_loss did not improve from 0.09831
#
# Epoch 16: val_loss did not improve from 0.09831
# Epoch 16: early stopping
# 44-th combination = (False, True, True, 256, 365, 0.2)
#  train accuracy: [0.26070117950439453, 0.510589063167572] and test accuracy: [0.005426472518593073, 0.0736645981669426]
# 46th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.09829, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.09829
#
# Epoch 3: val_loss improved from 0.09829 to 0.08527, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08527
#
# Epoch 5: val_loss did not improve from 0.08527
#
# Epoch 6: val_loss did not improve from 0.08527
#
# Epoch 7: val_loss did not improve from 0.08527
#
# Epoch 8: val_loss did not improve from 0.08527
# Epoch 8: early stopping
# 45-th combination = (False, True, False, 64, 7, 0.2)
#  train accuracy: [0.2156897485256195, 0.46442410349845886] and test accuracy: [0.005868193693459034, 0.07660413533449173]
# 47th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.09612, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.09612 to 0.08439, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.08439 to 0.08019, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08019
#
# Epoch 5: val_loss did not improve from 0.08019
#
# Epoch 6: val_loss did not improve from 0.08019
#
# Epoch 7: val_loss did not improve from 0.08019
#
# Epoch 8: val_loss did not improve from 0.08019
# Epoch 8: early stopping
# 46-th combination = (False, True, False, 64, 28, 0.2)
#  train accuracy: [0.2699449956417084, 0.519562304019928] and test accuracy: [0.006975257769227028, 0.08351800590753555]
# 48th combination:
#
# ...
#
# Epoch 2: val_loss did not improve from 0.08751
#
# Epoch 3: val_loss improved from 0.08751 to 0.08211, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08211
#
# Epoch 5: val_loss did not improve from 0.08211
#
# Epoch 6: val_loss did not improve from 0.08211
#
# Epoch 7: val_loss did not improve from 0.08211
#
# Epoch 8: val_loss did not improve from 0.08211
# Epoch 8: early stopping
# 54-th combination = (False, False, True, 64, 7, 0.2)
#  train accuracy: [0.13654212653636932, 0.3695160746574402] and test accuracy: [0.008406802080571651, 0.0916886180639267]
# 56th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.09911, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.09911 to 0.08140, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.08140
#
# Epoch 4: val_loss did not improve from 0.08140
#
# Epoch 5: val_loss did not improve from 0.08140
#
# Epoch 6: val_loss did not improve from 0.08140
#
# Epoch 7: val_loss did not improve from 0.08140
# Epoch 7: early stopping
# 55-th combination = (False, False, True, 64, 28, 0.2)
#  train accuracy: [0.25024062395095825, 0.5002405643463135] and test accuracy: [0.009769345633685589, 0.09883999824523926]
# 57th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.29091, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.29091 to 0.12038, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.12038
#
# Epoch 4: val_loss did not improve from 0.12038
#
# Epoch 5: val_loss did not improve from 0.12038
#
# Epoch 6: val_loss improved from 0.12038 to 0.11045, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.11045 to 0.08649, saving model to best_model.h5
#
# Epoch 8: val_loss improved from 0.08649 to 0.08256, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 0.08256 to 0.08234, saving model to best_model.h5
#
# Epoch 10: val_loss improved from 0.08234 to 0.08165, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.08165
#
# Epoch 12: val_loss did not improve from 0.08165
#
# Epoch 13: val_loss did not improve from 0.08165
#
# Epoch 14: val_loss did not improve from 0.08165
#
# Epoch 15: val_loss did not improve from 0.08165
# Epoch 15: early stopping
# 56-th combination = (False, False, True, 64, 365, 0.2)
#  train accuracy: [0.26612430810928345, 0.5158723592758179] and test accuracy: [0.004817359149456024, 0.06940719485282898]
# 58th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.19725, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.19725 to 0.08686, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.08686
#
# Epoch 4: val_loss did not improve from 0.08686
#
# Epoch 5: val_loss did not improve from 0.08686
#
# Epoch 6: val_loss did not improve from 0.08686
#
# Epoch 7: val_loss did not improve from 0.08686
# Epoch 7: early stopping
# 57-th combination = (False, False, True, 128, 7, 0.2)
#  train accuracy: [0.14994236826896667, 0.3872239291667938] and test accuracy: [0.007560687139630318, 0.08695220947265625]
# 59th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08226, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.08226
#
# Epoch 3: val_loss did not improve from 0.08226
#
# Epoch 4: val_loss did not improve from 0.08226
#
# Epoch 5: val_loss did not improve from 0.08226
#
# Epoch 6: val_loss did not improve from 0.08226
# Epoch 6: early stopping
# 58-th combination = (False, False, True, 128, 28, 0.2)
#  train accuracy: [0.23149649798870087, 0.4811408221721649] and test accuracy: [0.015976112335920334, 0.12639664113521576]
# 60th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.11779, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.11779
#
# Epoch 3: val_loss did not improve from 0.11779
#
# Epoch 4: val_loss improved from 0.11779 to 0.07773, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 0.07773 to 0.07752, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 0.07752
#
# Epoch 7: val_loss did not improve from 0.07752
#
# Epoch 8: val_loss did not improve from 0.07752
#
# Epoch 9: val_loss did not improve from 0.07752
#
# Epoch 10: val_loss did not improve from 0.07752
# Epoch 10: early stopping
# 59-th combination = (False, False, True, 128, 365, 0.2)
#  train accuracy: [0.26544997096061707, 0.5152183771133423] and test accuracy: [0.004843367729336023, 0.06959430873394012]
# 61th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.19147, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.19147 to 0.09969, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.09969
#
# Epoch 4: val_loss did not improve from 0.09969
#
# Epoch 5: val_loss did not improve from 0.09969
#
# Epoch 6: val_loss did not improve from 0.09969
#
# Epoch 7: val_loss improved from 0.09969 to 0.09292, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.09292
#
# Epoch 9: val_loss did not improve from 0.09292
#
# Epoch 10: val_loss improved from 0.09292 to 0.07796, saving model to best_model.h5
#
# Epoch 11: val_loss improved from 0.07796 to 0.07028, saving model to best_model.h5
#
# Epoch 12: val_loss did not improve from 0.07028
#
# Epoch 13: val_loss did not improve from 0.07028
#
# Epoch 14: val_loss did not improve from 0.07028
#
# Epoch 15: val_loss did not improve from 0.07028
#
# Epoch 16: val_loss did not improve from 0.07028
# Epoch 16: early stopping
# 60-th combination = (False, False, True, 256, 7, 0.2)
#  train accuracy: [0.06016765534877777, 0.24529096484184265] and test accuracy: [0.007560074795037508, 0.0869486927986145]
# 62th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.09456, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.09456 to 0.09042, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.09042
#
# Epoch 4: val_loss improved from 0.09042 to 0.08634, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.08634
#
# Epoch 6: val_loss did not improve from 0.08634
#
# Epoch 7: val_loss did not improve from 0.08634
#
# Epoch 8: val_loss did not improve from 0.08634
#
# Epoch 9: val_loss did not improve from 0.08634
# Epoch 9: early stopping
# 61-th combination = (False, False, True, 256, 28, 0.2)
#  train accuracy: [0.1875501573085785, 0.4330706000328064] and test accuracy: [0.023714376613497734, 0.15399472415447235]
# 63th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.09580, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.09580
#
# Epoch 3: val_loss did not improve from 0.09580
#
# Epoch 4: val_loss improved from 0.09580 to 0.08745, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.08745
#
# Epoch 6: val_loss did not improve from 0.08745
#
# Epoch 7: val_loss did not improve from 0.08745
#
# Epoch 8: val_loss did not improve from 0.08745
#
# Epoch 9: val_loss did not improve from 0.08745
# Epoch 9: early stopping
# 62-th combination = (False, False, True, 256, 365, 0.2)
#  train accuracy: [0.27182698249816895, 0.5213702917098999] and test accuracy: [0.03792016953229904, 0.19473101198673248]
# 64th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.11670, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.11670 to 0.09132, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.09132
#
# Epoch 4: val_loss did not improve from 0.09132
#
# Epoch 5: val_loss did not improve from 0.09132
#
# Epoch 6: val_loss did not improve from 0.09132
#
# Epoch 7: val_loss did not improve from 0.09132
# Epoch 7: early stopping
# 63-th combination = (False, False, False, 64, 7, 0.2)
#  train accuracy: [0.19155466556549072, 0.437669575214386] and test accuracy: [0.026586156338453293, 0.16305261850357056]
# 65th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.12433, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.12433 to 0.09126, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.09126
#
# Epoch 4: val_loss did not improve from 0.09126
#
# Epoch 5: val_loss improved from 0.09126 to 0.09064, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.09064 to 0.09015, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.09015
#
# Epoch 8: val_loss did not improve from 0.09015
#
# Epoch 9: val_loss did not improve from 0.09015
#
# Epoch 10: val_loss did not improve from 0.09015
#
# Epoch 11: val_loss did not improve from 0.09015
# Epoch 11: early stopping
# 64-th combination = (False, False, False, 64, 28, 0.2)
#  train accuracy: [0.22960560023784637, 0.4791717827320099] and test accuracy: [0.009607753716409206, 0.09801915287971497]
# 66th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.27653, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.27653 to 0.15273, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.15273 to 0.13189, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.13189
#
# Epoch 5: val_loss improved from 0.13189 to 0.12262, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.12262 to 0.09692, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 0.09692 to 0.07995, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 0.07995
#
# Epoch 9: val_loss did not improve from 0.07995
#
# Epoch 10: val_loss did not improve from 0.07995
#
# Epoch 11: val_loss did not improve from 0.07995
#
# Epoch 12: val_loss did not improve from 0.07995
# Epoch 12: early stopping
# 65-th combination = (False, False, False, 64, 365, 0.2)
#  train accuracy: [0.2720428705215454, 0.5215772986412048] and test accuracy: [0.008980792947113514, 0.09476704895496368]
# 67th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.20576, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.20576 to 0.12596, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.12596 to 0.12407, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.12407
#
# Epoch 5: val_loss improved from 0.12407 to 0.11660, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.11660 to 0.11634, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.11634
#
# Epoch 8: val_loss improved from 0.11634 to 0.09484, saving model to best_model.h5
#
# Epoch 9: val_loss did not improve from 0.09484
#
# Epoch 10: val_loss improved from 0.09484 to 0.07709, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 0.07709
#
# Epoch 12: val_loss improved from 0.07709 to 0.07202, saving model to best_model.h5
#
# Epoch 13: val_loss did not improve from 0.07202
#
# Epoch 14: val_loss improved from 0.07202 to 0.06388, saving model to best_model.h5
#
# Epoch 15: val_loss did not improve from 0.06388
#
# Epoch 16: val_loss did not improve from 0.06388
#
# Epoch 17: val_loss did not improve from 0.06388
#
# Epoch 18: val_loss did not improve from 0.06388
#
# Epoch 19: val_loss did not improve from 0.06388
# Epoch 19: early stopping
# 66-th combination = (False, False, False, 128, 7, 0.2)
#  train accuracy: [0.06554251909255981, 0.2560127377510071] and test accuracy: [0.006651502102613449, 0.08155674487352371]
# 68th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.09581, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.09581 to 0.08847, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.08847
#
# Epoch 4: val_loss did not improve from 0.08847
#
# Epoch 5: val_loss did not improve from 0.08847
#
# Epoch 6: val_loss did not improve from 0.08847
#
# Epoch 7: val_loss did not improve from 0.08847
# Epoch 7: early stopping
# 67-th combination = (False, False, False, 128, 28, 0.2)
#  train accuracy: [0.23568910360336304, 0.4854782223701477] and test accuracy: [0.00898629892617464, 0.0947960913181305]
# 69th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.11671, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.11671
#
# Epoch 3: val_loss did not improve from 0.11671
#
# Epoch 4: val_loss improved from 0.11671 to 0.08253, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.08253
#
# Epoch 6: val_loss did not improve from 0.08253
#
# Epoch 7: val_loss did not improve from 0.08253
#
# Epoch 8: val_loss did not improve from 0.08253
#
# Epoch 9: val_loss did not improve from 0.08253
# Epoch 9: early stopping
# 68-th combination = (False, False, False, 128, 365, 0.2)
#  train accuracy: [0.27202874422073364, 0.5215637683868408] and test accuracy: [0.010084696114063263, 0.10042259097099304]
# 70th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.12626, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.12626
#
# Epoch 3: val_loss did not improve from 0.12626
#
# Epoch 4: val_loss improved from 0.12626 to 0.10190, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.10190
#
# Epoch 6: val_loss improved from 0.10190 to 0.09028, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.09028
#
# Epoch 8: val_loss did not improve from 0.09028
#
# Epoch 9: val_loss did not improve from 0.09028
#
# Epoch 10: val_loss improved from 0.09028 to 0.07975, saving model to best_model.h5
#
# Epoch 11: val_loss improved from 0.07975 to 0.07786, saving model to best_model.h5
#
# Epoch 12: val_loss did not improve from 0.07786
#
# Epoch 13: val_loss did not improve from 0.07786
#
# Epoch 14: val_loss did not improve from 0.07786
#
# Epoch 15: val_loss did not improve from 0.07786
#
# Epoch 16: val_loss did not improve from 0.07786
# Epoch 16: early stopping
# 69-th combination = (False, False, False, 256, 7, 0.2)
#  train accuracy: [0.10595660656690598, 0.3255097568035126] and test accuracy: [0.08462879061698914, 0.2909102737903595]
# 71th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.08535, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.08535 to 0.07871, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.07871
#
# Epoch 4: val_loss did not improve from 0.07871
#
# Epoch 5: val_loss did not improve from 0.07871
#
# Epoch 6: val_loss did not improve from 0.07871
#
# Epoch 7: val_loss did not improve from 0.07871
# Epoch 7: early stopping
# 70-th combination = (False, False, False, 256, 28, 0.2)
#  train accuracy: [0.2293928563594818, 0.47894975543022156] and test accuracy: [0.0931536853313446, 0.3052108883857727]
# 72th combination:
#
# --------------------------------------------------------------------
#
# Epoch 1: val_loss improved from inf to 0.12686, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.12686
#
# Epoch 3: val_loss improved from 0.12686 to 0.08070, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.08070
#
# Epoch 5: val_loss did not improve from 0.08070
#
# Epoch 6: val_loss did not improve from 0.08070
#
# Epoch 7: val_loss did not improve from 0.08070
#
# Epoch 8: val_loss did not improve from 0.08070
# Epoch 8: early stopping
# 71-th combination = (False, False, False, 256, 365, 0.2)
#  train accuracy: [0.2769286632537842, 0.5262401103973389] and test accuracy: [0.04517676308751106, 0.21254825592041016]

# %%
hist = pd.DataFrame(hist)
hist = hist.sort_values(by=[7], ascending=True)
hist
# Out:
#         0      1      2    3    4    5  \
# 21   True  False   True  128    7  0.2
# 24   True  False   True  256    7  0.2
# 56  False  False   True   64  365  0.2
# 59  False  False   True  128  365  0.2
# 5    True   True   True  128  365  0.2
# ..    ...    ...    ...  ...  ...  ...
# 70  False  False  False  256   28  0.2
# 19   True  False   True   64   28  0.2
# 42  False   True   True  256    7  0.2
# 39  False   True   True  128    7  0.2
# 7    True   True   True  256   28  0.2
#
#                                              6  \
# 21  [0.20063577592372894, 0.44792383909225464]
# 24   [0.1542966365814209, 0.39280611276626587]
# 56   [0.26612430810928345, 0.5158723592758179]
# 59   [0.26544997096061707, 0.5152183771133423]
# 5     [0.2719452679157257, 0.5214837193489075]
# ..                                         ...
# 70   [0.2293928563594818, 0.47894975543022156]
# 19   [0.37717825174331665, 0.6141483783721924]
# 42  [0.21316806972026825, 0.46170127391815186]
# 39     [0.2671944797039032, 0.516908586025238]
# 7     [0.3393590450286865, 0.5825453400611877]
#
#                                               7
# 21  [0.004339824430644512, 0.06587734073400497]
# 24  [0.004807140212506056, 0.06933354586362839]
# 56  [0.004817359149456024, 0.06940719485282898]
# 59  [0.004843367729336023, 0.06959430873394012]
# 5   [0.004934459924697876, 0.07024571299552917]
# ..                                          ...
# 70     [0.0931536853313446, 0.3052108883857727]
# 19   [0.09971624612808228, 0.31577879190444946]
# 42   [0.12640412151813507, 0.35553357005119324]
# 39    [0.14569415152072906, 0.3816990256309509]
# 7    [0.19960731267929077, 0.44677433371543884]
#
# [72 rows x 8 columns]

# %%
print(
    f"Best Combination: \n first_additional_layer = {hist.iloc[0, 0]}\n second_additional_layer = {hist.iloc[0, 1]}\n third_additional_layer = {hist.iloc[0, 2]}\n n_neurons = {hist.iloc[0, 3]}\n n_batch_size = {hist.iloc[0, 4]}\n dropout = {hist.iloc[0, 5]}"
)
print("**************************")
print(f"Results Before Tunning:\n Test Set RMSE: {np.round(results, 4)[1]}\n")
print(f"Results After Tunning:\n Test Set RMSE: {np.round(hist.iloc[0, -1], 4)[1]}\n")
print(
    f"{np.round((results[1] - hist.iloc[0, -1][1])*100/np.round(results, 4)[1])}% Improvement"
)
# Out:
# Best Combination:
#  first_additional_layer = True
#  second_additional_layer = False
#  third_additional_layer = True
#  n_neurons = 128
#  n_batch_size = 7
#  dropout = 0.2
# **************************
# Results Before Tunning:
#  Test Set RMSE: 0.1384
#
# Results After Tunning:
#  Test Set RMSE: 0.0659
#
# 52.0% Improvement

# %%
(
    first_additional_layer,
    second_additional_layer,
    third_additional_layer,
    n_neurons,
    n_batch_size,
    dropout,
) = list(hist.iloc[0, :-2])

# %%
regressor = Sequential()
regressor.add(
    LSTM(
        units=n_neurons,
        return_sequences=True,
        input_shape=(X_train.shape[1], X_train.shape[2]),
    )
)
regressor.add(Dropout(dropout))

if first_additional_layer:
    regressor.add(LSTM(units=n_neurons, return_sequences=True))
    regressor.add(Dropout(dropout))

if second_additional_layer:
    regressor.add(LSTM(units=n_neurons, return_sequences=True))
    regressor.add(Dropout(dropout))

if third_additional_layer:
    regressor.add(GRU(units=n_neurons, return_sequences=True))
    regressor.add(Dropout(dropout))

regressor.add(LSTM(units=n_neurons, return_sequences=False))
regressor.add(Dropout(dropout))
regressor.add(Dense(units=1, activation="linear"))
regressor.compile(optimizer=tf.keras.optimizers.Adam(), loss="mse")

es = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=5)

file_path = "best_model.h5"

mc = ModelCheckpoint(
    file_path, monitor="val_loss", mode="min", verbose=1, save_best_only=True
)

regressor.fit(
    X_train,
    y_train,
    validation_split=0.3,
    epochs=200,
    batch_size=n_batch_size,
    callbacks=[es, mc],
    verbose=0,
)
# Out:
# Epoch 1: val_loss improved from inf to 0.08342, saving model to best_model.h5
# /home/samuell/.local/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss did not improve from 0.08342
#
# Epoch 3: val_loss did not improve from 0.08342
#
# Epoch 4: val_loss did not improve from 0.08342
#
# Epoch 5: val_loss did not improve from 0.08342
#
# Epoch 6: val_loss did not improve from 0.08342
# Epoch 6: early stopping

# %%
regressor.evaluate(X_test, y_test)
# Out:
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0605
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0596
# 0.059593118727207184

# %%
y_pred = regressor.predict(X_test)
# Out:
# 5/5 [==============================] - 1s 11ms/step

# %%
scaler = StandardScaler()
scaler.fit(df[[target_column]])
y_pred = regressor.predict(X_test)
unscaled_y_pred = scaler.inverse_transform([y_pred.flatten()])[0]
unscaled_y_test = scaler.inverse_transform([y_test.flatten()])[0]

import matplotlib.dates as mdates
data_length = len(unscaled_y_test)

fig, ax = plt.subplots(1, 1, figsize=(1280 / 96, 720 / 96))
ax.plot(dates[-data_length:], unscaled_y_test, label="actual")
ax.plot(dates[-data_length:], unscaled_y_pred, label="prediction")
ax.set_title("Prediction LSTM")
ax.set_ylabel("New Deaths")
ax.set_xlabel(date_column)
ax.legend()
ax.xaxis.set_major_locator(mdates.AutoDateLocator())
plt.show()
# Out:
# 5/5 [==============================] - 0s 11ms/step

# %%
from metrics import print_evaluation_metrics
print_evaluation_metrics(unscaled_y_pred, unscaled_y_test)
# Out:
# Evaluation Metrics:
# MSE: 1294258.73
# RMSE: 1137.65
# MAE: 1097.23
# MAPE: 332.87
# SMAPE: 116.18
